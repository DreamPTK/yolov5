# %%
# %cd yolov5

import utils
display = utils.notebook_init()
# Out:
# YOLOv5  v7.0-304-g22361691 Python-3.9.13 torch-2.2.2+cpu CPU
# Setup complete  (8 CPUs, 15.9 GB RAM, 14.6/244.1 GB disk)

# %%
# !python detect.py --img 640 --weights ThTaxSigns/data/model/ThTaxSigns.pt --conf 0.1  --source ThTaxSigns/data/images --project ThTaxSigns/data/output
# Out:
# detect: weights=['ThTaxSigns/data/model/ThTaxSigns.pt'], source=ThTaxSigns/data/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=ThTaxSigns/data/output, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-304-g22361691 Python-3.9.13 torch-2.2.2+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 E:\sign_project\yolov5\ThTaxSigns\data\images\testimg2.jpg: 576x640 1 unidentified_signs, 348.3ms
# Speed: 3.0ms pre-process, 348.3ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ThTaxSigns\data\output\exp2

# %%
display.Image(filename='ThTaxSigns/data/output/exp2/testimg2.jpg', width=600)
