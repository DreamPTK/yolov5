# %%
# !git clone https://github.com/DreamPTK/yolov5.git

# %% [markdown]
# ## Import Module

# %%
import utils
import os

display = utils.notebook_init()
# Out:
# YOLOv5  20ab307 Python-3.11.7 torch-2.3.0+cpu CPU
# Setup complete  (12 CPUs, 15.9 GB RAM, 32.0/450.0 GB disk)

# %% [markdown]
# ## Detect

# %%
# !python detect.py --img 640 --weights ThTaxSigns/data/models.pt --conf 0.4  --source ThTaxSigns/data/images --project ThTaxSigns/data/output --save-crop
# Out:
# detect: weights=['ThTaxSigns/data/models.pt'], source=ThTaxSigns/data/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=ThTaxSigns/data/output, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  20ab307 Python-3.11.7 torch-2.3.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2 E:\test\sign_project\yolov5\ThTaxSigns\data\images\testimg2.jpg: 576x640 1 unidentified_signs, 172.5ms
# image 2/2 E:\test\sign_project\yolov5\ThTaxSigns\data\images\testimg3.jpg: 416x640 3 unidentified_signss, 130.9ms
# Speed: 9.7ms pre-process, 151.7ms inference, 43.9ms NMS per image at shape (1, 3, 640, 640)
# ...

# %% [markdown]
# ## Visualize output

# %% [markdown]
# ### Display result

# %%
display.Image(filename='ThTaxSigns/data/output/exp2/testimg2.jpg', width=400)

# %%
display.Image(filename='ThTaxSigns/data/output/exp2/testimg3.jpg', width=400)

# %% [markdown]
# #### Display crop output

# %%
from IPython.display import display, Image

def display_images_from_folder(folder_path):
    # List all files in the folder
    files = os.listdir(folder_path)
    
    # Filter out only image files
    image_files = [file for file in files if file.endswith(('.jpg', '.jpeg', '.png', '.gif'))]
    
    # Display each image
    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        display(Image(filename=image_path, width=300))

# %%
folder_path = "E:/test/sign_project/yolov5/ThTaxSigns/data/output/exp2/crops/unidentified_signs"

display_images_from_folder(folder_path )
